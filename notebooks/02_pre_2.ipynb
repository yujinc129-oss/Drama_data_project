# %% [markdown]
# <a href="https://colab.research.google.com/github/yujinc129-oss/Drama_data_project/blob/main/notebooks/02_pre_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #2차 전처리

# %%
drama = pd.read_json('https://github.com/yujinc129-oss/Drama_data_project/raw/refs/heads/main/data/processed/actor_drop.json',orient='records')

# %%
drama
# Out:
#               actor                   drama          role  gender  \
# 0         junghaein                snowdrop     Main Role    Male
# 1         junghaein                    d.p.     Main Role    Male
# 2         junghaein        apieceofyourmind     Main Role    Male
# 3         junghaein          onespringnight     Main Role    Male
# 4         junghaein      somethingintherain     Main Role    Male
# ...             ...                     ...           ...     ...
# 2172    kimjongkook            theproducers  Support Role    Male
# 2173    jungyoonhak  myunfortunateboyfriend     Main Role    Male
# 2174  jungjoonyoung                thelover     Main Role    Male
# 2175        kimjoon            cityofthesun     Main Role    Male
# 2176     kimyoungae           killme,healme  Support Role  Female
#
#                                    Genres                Aired On  \
# 0               [drama, society, romance]     [saturday,  sunday]
# ...

# %%
#컬럼명 변환
drama = drama.rename(columns={'Genres':'genres','Aired On':'day','Original Network' :'network','score_weighted':'score'})

# %%
#리스트 안 공백 제거
drama['genres'] = drama['genres'].apply(lambda x: [genres.strip() for genres in x])
drama['network'] = drama['network'].apply(lambda x: [network.strip() for network in x])
drama['day'] = drama['day'].apply(lambda x: [day.strip() for day in x])

# %%
drama
# Out:
#               actor                   drama          role  gender  \
# 0         junghaein                snowdrop     Main Role    Male
# 1         junghaein                    d.p.     Main Role    Male
# 2         junghaein        apieceofyourmind     Main Role    Male
# 3         junghaein          onespringnight     Main Role    Male
# 4         junghaein      somethingintherain     Main Role    Male
# ...             ...                     ...           ...     ...
# 2172    kimjongkook            theproducers  Support Role    Male
# 2173    jungyoonhak  myunfortunateboyfriend     Main Role    Male
# 2174  jungjoonyoung                thelover     Main Role    Male
# 2175        kimjoon            cityofthesun     Main Role    Male
# 2176     kimyoungae           killme,healme  Support Role  Female
#
#                                    genres                    day  \
# 0               [drama, society, romance]     [saturday, sunday]
# ...

# %%
gen_list = drama.genres.sum()
gen_list.sort()
gen_np = pd.DataFrame(gen_list)
gen_np.value_counts()
# Out:
# 0
# romance     1488
# drama       1439
# comedy       944
# thriller     874
# society      592
# sf           453
# action       271
# hist_war     196
# youth        123
# music         63
# food          58
# sports        22
# etc            2
# Name: count, dtype: int64

# %%
#네트워크 변수 수정  총 12개 네트워크
net_dict={
          'ETC_P':['IQIYI', 'VIUTV', 'OKSUSU','BS JAPAN',
                  'VLIVE','VIKI','NAVER TV CAST', 'DAUM KAKAO TV'],
          'ENT':['MNET','DRAMAX','OCN'],
          'GPC':['TV CHOSUN', 'CHANNEL A', 'MBN'],
          'KBS' : ['KBS1','KBS2'],
          'MBC': ['MBC','MBC DRAMANET', 'MBC EVERY1'],
          'SBS' : ['SBS','SBS PLUS']}

# %%
network = pd.DataFrame(drama.network.sum())
network.value_counts()
# Out:
# 0
# TVN              458
# KBS2             431
# MBC              335
# SBS              327
# NETFLIX          281
# JTBC             225
# VIKI             142
# OCN              123
# KBS1              59
# IQIYI             48
# NAVER TV CAST     36
# TV CHOSUN         28
# VIUTV             27
# MBN               27
# CHANNEL A         23
# DAUM KAKAO TV     17
# OKSUSU            12
# DRAMAX            12
# MBC EVERY1         6
# MNET               5
# SBS PLUS           5
# MBC DRAMANET       5
# BS JAPAN           3
# VLIVE              1
# Name: count, dtype: int64

# %%
def net_change(network_list):
  new = set()

  for x in network_list:
    k= False
    for key, value in net_dict.items():
      if x in value:
        new.add(key)s
        k=True

    if k==False:
        new.add(x)
  return list(new)


net_change(['NAVER TV CAST', 'NETFLIX'])
# Out:
# ['NETFLIX', 'WEB']

# %%
for x in range(len(drama.network)):
  drama.network[x] = net_change(drama.network[x])
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   drama.network[x] = net_change(drama.network[x])
# /tmp/ipython-input-738861697.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   drama.network[x] = net_change(drama.network[x])
# /tmp/ipython-input-738861697.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# ...

# %%
drama
# Out:
#               actor                   drama          role  gender  \
# 0         junghaein                snowdrop     Main Role    Male
# 1         junghaein                    d.p.     Main Role    Male
# 2         junghaein        apieceofyourmind     Main Role    Male
# 3         junghaein          onespringnight     Main Role    Male
# 4         junghaein      somethingintherain     Main Role    Male
# ...             ...                     ...           ...     ...
# 2172    kimjongkook            theproducers  Support Role    Male
# 2173    jungyoonhak  myunfortunateboyfriend     Main Role    Male
# 2174  jungjoonyoung                thelover     Main Role    Male
# 2175        kimjoon            cityofthesun     Main Role    Male
# 2176     kimyoungae           killme,healme  Support Role  Female
#
#                                    genres                    day  \
# 0               [drama, society, romance]     [saturday, sunday]
# ...

# %%
drama.to_json('02_pre_2', orient='records')
